# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Sanitation.csv")

# %%
df
# Out:
#          ULB Name  Public Toilets  Community Toilets  She Toilets  \
# 0        Adilabad             8.0                NaN          NaN
# 1   Andol-Jogipet             NaN                NaN          NaN
# 2          Armoor             4.0                NaN          NaN
# 3       Atchampet             NaN                NaN          NaN
# 4       Badangpet             NaN                NaN          NaN
# ..            ...             ...                ...          ...
# 67      Vikarabad             3.0                NaN          NaN
# 68     Wanaparthy             NaN                NaN          NaN
# 69       Warangal             1.0                NaN          NaN
# 70       Yellandu             NaN                NaN          NaN
# 71     Zaheerabad             NaN                NaN          NaN
#
#     ODF Declared Wards  ODF Non Declared Wards  \
# 0                   36                       0
# 1                   10                      10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ULB Name                                 72 non-null     object
#  1   Public Toilets                           31 non-null     float64
#  2   Community Toilets                        13 non-null     float64
#  3   She Toilets                              10 non-null     float64
#  4   ODF Declared Wards                       72 non-null     int64
#  5   ODF Non Declared Wards                   72 non-null     int64
#  6   Compost Yard Location & Extent (Acrs)    72 non-null     float64
#  7   Dry Resourse Collection Center (Yes/No)  60 non-null     object
#  8   % of Door to Door Collection             72 non-null     float64
#  9   Tractors                                 72 non-null     int64
# ...

# %%
df.describe()
# Out:
#        Public Toilets  Community Toilets  She Toilets  ODF Declared Wards  \
# count       31.000000          13.000000    10.000000           72.000000
# mean         3.419355           1.538462     1.300000           23.291667
# std          3.253451           1.853617     0.483046           10.864644
# min          0.000000           0.000000     1.000000            0.000000
# 25%          1.000000           1.000000     1.000000           20.000000
# 50%          2.000000           1.000000     1.000000           20.000000
# 75%          4.000000           2.000000     1.750000           30.250000
# max         16.000000           7.000000     2.000000           50.000000
#
#        ODF Non Declared Wards  Compost Yard Location & Extent (Acrs)  \
# count               72.000000                              72.000000
# mean                 3.958333                               5.993194
# std                 10.161287                              10.094007
# ...

# %%
df.replace("?", np.nan, inplace = True)
df.head(10)
# Out:
#         ULB Name  Public Toilets  Community Toilets  She Toilets  \
# 0       Adilabad             8.0                NaN          NaN
# 1  Andol-Jogipet             NaN                NaN          NaN
# 2         Armoor             4.0                NaN          NaN
# 3      Atchampet             NaN                NaN          NaN
# 4      Badangpet             NaN                NaN          NaN
# 5      Badepally             3.0                NaN          1.0
# 6    Bellampalle             NaN                NaN          NaN
# 7        Bhainsa             3.0                NaN          2.0
# 8        Bhongir             NaN                NaN          NaN
# 9   Bhupalapally             5.0                NaN          NaN
#
#    ODF Declared Wards  ODF Non Declared Wards  \
# 0                  36                       0
# 1                  10                      10
# 2                  23                       0
# 3                  20                       0
# ...

# %%
df.replace("NaN", "Missing Value") #Using replace function for removig missing value
# Out:
#          ULB Name  Public Toilets  Community Toilets  She Toilets  \
# 0        Adilabad             8.0                NaN          NaN
# 1   Andol-Jogipet             NaN                NaN          NaN
# 2          Armoor             4.0                NaN          NaN
# 3       Atchampet             NaN                NaN          NaN
# 4       Badangpet             NaN                NaN          NaN
# ..            ...             ...                ...          ...
# 67      Vikarabad             3.0                NaN          NaN
# 68     Wanaparthy             NaN                NaN          NaN
# 69       Warangal             1.0                NaN          NaN
# 70       Yellandu             NaN                NaN          NaN
# 71     Zaheerabad             NaN                NaN          NaN
#
#     ODF Declared Wards  ODF Non Declared Wards  \
# 0                   36                       0
# 1                   10                      10
# ...

# %%
avg_1 = df["Public Toilets"].astype("float").mean(axis = 0)  #Axis=0 Column

# %%
avg_1
# Out:
# 3.4193548387096775

# %%
df["Public Toilets"].replace(np.nan, avg_1, inplace = True)

# %%
df
# Out:
#          ULB Name  Public Toilets  Community Toilets  She Toilets  \
# 0        Adilabad        8.000000                NaN          NaN
# 1   Andol-Jogipet        3.419355                NaN          NaN
# 2          Armoor        4.000000                NaN          NaN
# 3       Atchampet        3.419355                NaN          NaN
# 4       Badangpet        3.419355                NaN          NaN
# ..            ...             ...                ...          ...
# 67      Vikarabad        3.000000                NaN          NaN
# 68     Wanaparthy        3.419355                NaN          NaN
# 69       Warangal        1.000000                NaN          NaN
# 70       Yellandu        3.419355                NaN          NaN
# 71     Zaheerabad        3.419355                NaN          NaN
#
#     ODF Declared Wards  ODF Non Declared Wards  \
# 0                   36                       0
# 1                   10                      10
# ...

# %%
avg_2 = df["Community Toilets"].astype("float").mean(axis = 0)

# %%
avg_2
# Out:
# 1.5384615384615385

# %%
df["Community Toilets"].replace(np.nan, avg_1, inplace = True)

# %%
df
# Out:
#          ULB Name  Public Toilets  Community Toilets  She Toilets  \
# 0        Adilabad        8.000000           3.419355          NaN
# 1   Andol-Jogipet        3.419355           3.419355          NaN
# 2          Armoor        4.000000           3.419355          NaN
# 3       Atchampet        3.419355           3.419355          NaN
# 4       Badangpet        3.419355           3.419355          NaN
# ..            ...             ...                ...          ...
# 67      Vikarabad        3.000000           3.419355          NaN
# 68     Wanaparthy        3.419355           3.419355          NaN
# 69       Warangal        1.000000           3.419355          NaN
# 70       Yellandu        3.419355           3.419355          NaN
# 71     Zaheerabad        3.419355           3.419355          NaN
#
#     ODF Declared Wards  ODF Non Declared Wards  \
# 0                   36                       0
# 1                   10                      10
# ...

# %%
avg_3 = df["She Toilets"].astype("float").mean(axis = 0)
df["She Toilets"].replace(np.nan, avg_1, inplace = True)
df
# Out:
#          ULB Name  Public Toilets  Community Toilets  She Toilets  \
# 0        Adilabad        8.000000           3.419355     3.419355
# 1   Andol-Jogipet        3.419355           3.419355     3.419355
# 2          Armoor        4.000000           3.419355     3.419355
# 3       Atchampet        3.419355           3.419355     3.419355
# 4       Badangpet        3.419355           3.419355     3.419355
# ..            ...             ...                ...          ...
# 67      Vikarabad        3.000000           3.419355     3.419355
# 68     Wanaparthy        3.419355           3.419355     3.419355
# 69       Warangal        1.000000           3.419355     3.419355
# 70       Yellandu        3.419355           3.419355     3.419355
# 71     Zaheerabad        3.419355           3.419355     3.419355
#
#     ODF Declared Wards  ODF Non Declared Wards  \
# 0                   36                       0
# 1                   10                      10
# ...

# %%
df['Dry Resourse Collection Center (Yes/No)'].value_counts()
# Out:
# YES    34
# NO     26
# Name: Dry Resourse Collection Center (Yes/No), dtype: int64

# %%
df["Dry Resourse Collection Center (Yes/No)"].replace(np.nan, "YES", inplace = True)

# %%
df['Dry Resourse Collection Center (Yes/No)'].value_counts()
# Out:
# YES    46
# NO     26
# Name: Dry Resourse Collection Center (Yes/No), dtype: int64

# %%
df["Compost Yard Location & Extent (Acrs)"].isnull().value_counts()
# Out:
# False    72
# Name: Compost Yard Location & Extent (Acrs), dtype: int64

# %%
df.isnull().value_counts()
# Out:
# ULB Name  Public Toilets  Community Toilets  She Toilets  ODF Declared Wards  ODF Non Declared Wards  Compost Yard Location & Extent (Acrs)  Dry Resourse Collection Center (Yes/No)  % of Door to Door Collection  Tractors  Autos  Tricycles  Pushcarts  Regular Workers  Out Sourced Workers  Government Hospitals  Private Hospitals  Urban Health Centres  Garbage generation/day (Mts)  Garbage lifted/day (Mts)
# False     False           False              False        False               False                   False                                  False                                    False                         False     False  False      False      False            False                False                 False              False                 False                         False                       72
# dtype: int64

# %% [markdown]
# <br>**TILL NOW WE DID**<br>
#
# <b>1.Read Data<br>
# <br>2.Pre-processing<br>
# <br>3.Replacing Missing values<br>
# <br>4.Data Type mismatch<br>
# <br>5.Data Formatting<br>
# <br>6.Data Normalization<br>

# %% [markdown]
# <br>**Now let start the analysis with Exploratory Data Analysis (EDA)**<br>

# %%
import seaborn as sns
# %matplotlib inline

# %%
df.corr()
# Out:
#                                        Public Toilets  Community Toilets  \
# Public Toilets                               1.000000           0.090620
# Community Toilets                            0.090620           1.000000
# She Toilets                                  0.127611          -0.073221
# ODF Declared Wards                           0.363184          -0.066158
# ODF Non Declared Wards                      -0.048543           0.071861
# Compost Yard Location & Extent (Acrs)        0.665034          -0.031040
# % of Door to Door Collection                 0.025070           0.034922
# Tractors                                     0.294654          -0.165575
# Autos                                        0.239731           0.020534
# Tricycles                                    0.008860           0.064823
# Pushcarts                                    0.354054          -0.066291
# Regular Workers                              0.572517           0.025726
# ...

# %%
df
# Out:
#          ULB Name  Public Toilets  Community Toilets  She Toilets  \
# 0        Adilabad        8.000000           3.419355     3.419355
# 1   Andol-Jogipet        3.419355           3.419355     3.419355
# 2          Armoor        4.000000           3.419355     3.419355
# 3       Atchampet        3.419355           3.419355     3.419355
# 4       Badangpet        3.419355           3.419355     3.419355
# ..            ...             ...                ...          ...
# 67      Vikarabad        3.000000           3.419355     3.419355
# 68     Wanaparthy        3.419355           3.419355     3.419355
# 69       Warangal        1.000000           3.419355     3.419355
# 70       Yellandu        3.419355           3.419355     3.419355
# 71     Zaheerabad        3.419355           3.419355     3.419355
#
#     ODF Declared Wards  ODF Non Declared Wards  \
# 0                   36                       0
# 1                   10                      10
# ...

# %%
df[['Public Toilets','ODF Declared Wards']].corr()
# Out:
#                     Public Toilets  ODF Declared Wards
# Public Toilets            1.000000            0.363184
# ODF Declared Wards        0.363184            1.000000

# %%
df[['Public Toilets','Compost Yard Location & Extent (Acrs)']].corr()
# Out:
#                                        Public Toilets  \
# Public Toilets                               1.000000
# Compost Yard Location & Extent (Acrs)        0.665034
#
#                                        Compost Yard Location & Extent (Acrs)
# Public Toilets                                                      0.665034
# Compost Yard Location & Extent (Acrs)                               1.000000

# %%
df[['Public Toilets','% of Door to Door Collection']].corr()
# Out:
#                               Public Toilets  % of Door to Door Collection
# Public Toilets                       1.00000                       0.02507
# % of Door to Door Collection         0.02507                       1.00000

# %%
df[['Public Toilets','Garbage generation/day (Mts)']].corr()
# Out:
#                               Public Toilets  Garbage generation/day (Mts)
# Public Toilets                      1.000000                      0.551936
# Garbage generation/day (Mts)        0.551936                      1.000000

# %%
df[['Public Toilets','Garbage lifted/day (Mts)']].corr()
# Out:
#                           Public Toilets  Garbage lifted/day (Mts)
# Public Toilets                  1.000000                  0.158754
# Garbage lifted/day (Mts)        0.158754                  1.000000

# %% [markdown]
# **REGRESSION PLOTS**

# %%
sns.regplot(x="Public Toilets", y="Garbage lifted/day (Mts)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 220.52007203151965)

# %%
sns.regplot(x="Public Toilets", y="Garbage generation/day (Mts)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 247.0373145994584)

# %%
sns.regplot(x="ODF Declared Wards", y="Garbage generation/day (Mts)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 222.1457431969945)

# %%
sns.regplot(x="Compost Yard Location & Extent (Acrs)", y="Garbage generation/day (Mts)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 227.63832942584273)

# %%
sns.regplot(x="% of Door to Door Collection", y="Garbage generation/day (Mts)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 219.6005664699035)

# %%
plt.figure(figsize=(15, 15))
plt.xticks(rotation=90)
plt.bar(df.loc[:72,'ULB Name'],df.loc[:72,'Public Toilets'],label='Public Toilets')
plt.bar(df.loc[:72,'ULB Name'],df.loc[:72,'Community Toilets'],bottom=df.loc[:72,'Public Toilets'],label='Community Toilets')
plt.bar(df.loc[:72,'ULB Name'],df.loc[:72,'She Toilets'],bottom=df.loc[:72,'Public Toilets']+df.loc[:72,'Community Toilets'],label='She Toilets')
plt.xlabel('ULB Name')
plt.ylabel("Toilets")
plt.title("Toilets in Telangana")

plt.legend()

# %%
plt.figure(figsize=(15, 20))
plt.xticks(rotation=90)
plt.bar(df.loc[:72,'ULB Name'],df.loc[:72,'ODF Declared Wards'],label='ODF Declared Wards')
plt.bar(df.loc[:72,'ULB Name'],df.loc[:72,'ODF Non Declared Wards'],bottom=df.loc[:72,'ODF Declared Wards'],label='ODF Non Declared Wards')

plt.xlabel('ULB Name')
plt.ylabel("ODF Declared Wards")
plt.title("ODF wards in Telangana")
plt.legend()

# %%
plt.figure(figsize=(15, 20))
plt.xticks(rotation=90)
plt.bar(df.loc[:72,'ULB Name'],df.loc[:72,'% of Door to Door Collection'],label='% of Door to Door Collection')


plt.xlabel('ULB Name')
plt.ylabel("Waste Collection")
plt.title("waste collection in Telangana")
plt.legend()

# %%
plt.figure(figsize=(15, 20))
plt.xticks(rotation=90)
plt.scatter(df.loc[:72,'ULB Name'],df.loc[:72,'Regular Workers'],label='Regular Workers')
plt.scatter(df.loc[:72,'ULB Name'],df.loc[:72,'Out Sourced Workers'],label='Out Sourced Workers')

plt.xlabel('ULB Name')
plt.ylabel("Workers")
plt.title("Municipal workers in Telangana")
plt.legend()

# %%
plt.figure(figsize=(15, 20))
plt.xticks(rotation=90)
plt.bar(df.loc[:72,'ULB Name'],df.loc[:72,'Garbage generation/day (Mts)'],label='Garbage generation/day (Mts)')
plt.bar(df.loc[:72,'ULB Name'],df.loc[:72,'Garbage lifted/day (Mts)'],label='Garbage lifted/day (Mts)')

plt.xlabel('ULB Name')
plt.ylabel("Garbage")
plt.title("Garbage generation/lifted per day in Telangana")
plt.legend()
